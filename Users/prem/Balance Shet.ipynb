# %%
import pandas as pd
import numpy as np
import os
import re

# %%
df = pd.read_csv(r'G:\project\Balance Sheet\Reliance.csv', sep='|', index_col=0)

# %%
df
# Out:
#                                                  Mar 19      Mar 18  \
# NaN                                             12 mths     12 mths
# Equity Share Capital                           6,339.00    6,335.00
# Total Share Capital                            6,339.00    6,335.00
# Reserves and Surplus                         398,983.00  308,297.00
# Total Reserves and Surplus                   398,983.00  308,297.00
# Total Shareholders Funds                     405,322.00  314,632.00
# Equity Share Application Money                     0.00       15.00
# Long Term Borrowings                         118,098.00   81,596.00
# Deferred Tax Liabilities [Net]                47,317.00   27,926.00
# Other Long Term Liabilities                      504.00      504.00
# Long Term Provisions                           2,483.00    2,205.00
# Total Non-Current Liabilities                168,402.00  112,231.00
# Short Term Borrowings                         39,097.00   15,239.00
# ...

# %%
df.dropna(how='all', axis=1, inplace=True)

# %%
df
# Out:
#                                                  Mar 19      Mar 18  \
# NaN                                             12 mths     12 mths
# Equity Share Capital                           6,339.00    6,335.00
# Total Share Capital                            6,339.00    6,335.00
# Reserves and Surplus                         398,983.00  308,297.00
# Total Reserves and Surplus                   398,983.00  308,297.00
# Total Shareholders Funds                     405,322.00  314,632.00
# Equity Share Application Money                     0.00       15.00
# Long Term Borrowings                         118,098.00   81,596.00
# Deferred Tax Liabilities [Net]                47,317.00   27,926.00
# Other Long Term Liabilities                      504.00      504.00
# Long Term Provisions                           2,483.00    2,205.00
# Total Non-Current Liabilities                168,402.00  112,231.00
# Short Term Borrowings                         39,097.00   15,239.00
# ...

# %%
df.dropna(how='all', axis=0, inplace=True)

# %%
df
# Out:
#                                                  Mar 19      Mar 18  \
# NaN                                             12 mths     12 mths
# Equity Share Capital                           6,339.00    6,335.00
# Total Share Capital                            6,339.00    6,335.00
# Reserves and Surplus                         398,983.00  308,297.00
# Total Reserves and Surplus                   398,983.00  308,297.00
# Total Shareholders Funds                     405,322.00  314,632.00
# Equity Share Application Money                     0.00       15.00
# Long Term Borrowings                         118,098.00   81,596.00
# Deferred Tax Liabilities [Net]                47,317.00   27,926.00
# Other Long Term Liabilities                      504.00      504.00
# Long Term Provisions                           2,483.00    2,205.00
# Total Non-Current Liabilities                168,402.00  112,231.00
# Short Term Borrowings                         39,097.00   15,239.00
# ...

# %%
df.drop(index=np.nan, inplace=True)

# %%
df
# Out:
#                                                  Mar 19      Mar 18  \
# Equity Share Capital                           6,339.00    6,335.00
# Total Share Capital                            6,339.00    6,335.00
# Reserves and Surplus                         398,983.00  308,297.00
# Total Reserves and Surplus                   398,983.00  308,297.00
# Total Shareholders Funds                     405,322.00  314,632.00
# Equity Share Application Money                     0.00       15.00
# Long Term Borrowings                         118,098.00   81,596.00
# Deferred Tax Liabilities [Net]                47,317.00   27,926.00
# Other Long Term Liabilities                      504.00      504.00
# Long Term Provisions                           2,483.00    2,205.00
# Total Non-Current Liabilities                168,402.00  112,231.00
# Short Term Borrowings                         39,097.00   15,239.00
# Trade Payables                                88,241.00   88,675.00
# ...

# %%
df.index
# Out:
# Index(['Equity Share Capital', 'Total Share Capital', 'Reserves and Surplus',
#        'Total Reserves and Surplus', 'Total Shareholders Funds',
#        'Equity Share Application Money', 'Long Term Borrowings',
#        'Deferred Tax Liabilities [Net]', 'Other Long Term Liabilities',
#        'Long Term Provisions', 'Total Non-Current Liabilities',
#        'Short Term Borrowings', 'Trade Payables', 'Other Current Liabilities',
#        'Short Term Provisions', 'Total Current Liabilities',
#        'Total Capital And Liabilities', 'Tangible Assets', 'Intangible Assets',
#        'Capital Work-In-Progress', 'Intangible Assets Under Development',
#        'Fixed Assets', 'Non-Current Investments',
#        'Long Term Loans And Advances', 'Other Non-Current Assets',
#        'Total Non-Current Assets', 'Current Investments', 'Inventories',
#        'Trade Receivables', 'Cash And Cash Equivalents',
#        'Short Term Loans And Advances', 'OtherCurrentAssets',
# ...

# %%
for i in df.index:
    if i.startswith('Total'):
        print(i)
# Out:
# Total Share Capital
# Total Reserves and Surplus
# Total Shareholders Funds
# Total Non-Current Liabilities
# Total Current Liabilities
# Total Capital And Liabilities
# Total Non-Current Assets
# Total Current Assets
# Total Assets
